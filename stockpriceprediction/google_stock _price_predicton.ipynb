# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout

# %%
data = pd.read_csv('Google_train_data.csv')
data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
data["Close"]=pd.to_numeric(data.Close,errors='coerce')
data = data.dropna()
trainData = data.iloc[:,4:5].values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1149 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1149 non-null   object
#  1   Open    1149 non-null   float64
#  2   High    1149 non-null   float64
#  3   Low     1149 non-null   float64
#  4   Close   1149 non-null   float64
#  5   Volume  1149 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 62.8+ KB

# %%
sc = MinMaxScaler(feature_range=(0,1))
trainData = sc.fit_transform(trainData)
trainData.shape
# Out:
# (1149, 1)

# %%
X_train = []
y_train = []

for i in range (60,1149):
    X_train.append(trainData[i-60:i,0]) 
    y_train.append(trainData[i,0])

X_train,y_train = np.array(X_train),np.array(y_train)

# %%
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_train.shape
# Out:
# (1089, 60, 1)

# %%
model = Sequential()

model.add(LSTM(units=100, return_sequences = True, input_shape =(X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units =1))
model.compile(optimizer='adam',loss="mean_squared_error")

# %%
hist = model.fit(X_train, y_train, epochs = 20, batch_size = 32, verbose=2)
# Out:
# Epoch 1/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 146ms/step
# Epoch 2/20
# 35/35 - 5s - loss: 0.0013 - 5s/epoch - 138ms/step
# Epoch 3/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 139ms/step
# Epoch 4/20
# 35/35 - 5s - loss: 0.0017 - 5s/epoch - 135ms/step
# Epoch 5/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 146ms/step
# Epoch 6/20
# 35/35 - 5s - loss: 0.0015 - 5s/epoch - 132ms/step
# Epoch 7/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 132ms/step
# Epoch 8/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 141ms/step
# Epoch 9/20
# 35/35 - 5s - loss: 0.0013 - 5s/epoch - 131ms/step
# Epoch 10/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 130ms/step
# Epoch 11/20
# 35/35 - 5s - loss: 0.0015 - 5s/epoch - 134ms/step
# Epoch 12/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 133ms/step
# Epoch 13/20
# 35/35 - 4s - loss: 0.0015 - 4s/epoch - 128ms/step
# Epoch 14/20
# 35/35 - 5s - loss: 0.0015 - 5s/epoch - 132ms/step
# Epoch 15/20
# 35/35 - 5s - loss: 0.0017 - 5s/epoch - 139ms/step
# Epoch 16/20
# 35/35 - 4s - loss: 0.0017 - 4s/epoch - 128ms/step
# Epoch 17/20
# 35/35 - 4s - loss: 0.0015 - 4s/epoch - 128ms/step
# Epoch 18/20
# 35/35 - 5s - loss: 0.0013 - 5s/epoch - 134ms/step
# Epoch 19/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 132ms/step
# Epoch 20/20
# 35/35 - 5s - loss: 0.0014 - 5s/epoch - 129ms/step

# %%
plt.plot(hist.history['loss'])
plt.title('Training model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
testData = pd.read_csv('Google_test_data.csv')
testData["Close"]=pd.to_numeric(testData.Close,errors='coerce')
testData = testData.dropna()
testData = testData.iloc[:,4:5]
y_test = testData.iloc[60:,0:].values 
inputClosing = testData.iloc[:,0:].values 
inputClosing_scaled = sc.transform(inputClosing)
inputClosing_scaled.shape
X_test = []
length = len(testData)
timestep = 60
for i in range(timestep,length):  
    X_test.append(inputClosing_scaled[i-timestep:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
X_test.shape
# Out:
# (192, 60, 1)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 6/6 [==============================] - 1s 32ms/step
# array([[1.0067997 ],
#        [1.0294185 ],
#        [1.0819938 ],
#        [0.9721589 ],
#        [1.012469  ],
#        [0.8965261 ],
#        [1.0866737 ],
#        [1.1037221 ],
#        [1.1130815 ],
#        [1.0664457 ],
#        [0.9117408 ],
#        [1.0621127 ],
#        [0.91174823],
#        [0.80321574],
#        [1.0807649 ],
#        [0.8412607 ],
#        [1.1015484 ],
#        [1.0235515 ],
#        [1.044446  ],
#        [1.0557486 ],
#        [0.56906885],
#        [1.1072557 ],
#        [0.7136559 ],
#        [1.0688035 ],
#        [1.0824331 ],
#        [1.0961838 ],
#        [1.0547038 ],
#        [0.9257877 ],
#        [0.93218994],
#        [1.0431482 ],
#        [0.84713286],
#        [0.93155026],
#        [0.90391904],
#        [0.9868413 ],
#        [1.0800654 ],
#        [0.9781074 ],
#        [0.99834204],
#        [1.0021908 ],
#        [0.922791  ],
#        [0.71224236],
#        [1.0507896 ],
#        [0.82187396],
#        [1.0709945 ],
#        [0.9968159 ],
#        [1.0564854 ],
#        [1.0286577 ],
#        [1.0164948 ],
#        [1.1046916 ],
#        [0.90047646],
#        [1.0450569 ],
#        [0.9766587 ],
#        [0.6703714 ],
#        [0.94432914],
#        [0.93612427],
#        [1.122639  ],
#        [0.99343026],
#        [0.9969007 ],
#        [1.0714848 ],
#        [0.9535021 ],
#        [0.8205327 ],
#        [1.1046703 ],
#        [0.79389906],
#        [0.65107393],
#        [1.1192609 ],
#        [1.0900238 ],
#        [0.99979126],
#        [1.0948291 ],
#        [0.7420453 ],
#        [0.9773823 ],
#        [0.8530658 ],
#        [0.9098445 ],
#        [0.98376536],
#        [1.053034  ],
#        [1.1247761 ],
#        [1.0189265 ],
#        [0.99376047],
#        [0.95338356],
#        [0.88833356],
#        [1.0211152 ],
#        [0.92593634],
#        [1.0061677 ],
#        [0.9775144 ],
#        [0.91461   ],
#        [1.0242873 ],
#        [1.0450395 ],
#        [0.8133552 ],
#        [1.0058105 ],
#        [1.0811305 ],
#        [1.0016135 ],
#        [0.9780685 ],
#        [1.0614502 ],
#        [1.032171  ],
#        [0.89228314],
#        [0.71899855],
#        [0.9743837 ],
#        [1.1123726 ],
#        [1.1679702 ],
#        [1.1763892 ],
#        [1.1554986 ],
#        [1.0955933 ],
#        [1.0007703 ],
#        [0.9387183 ],
#        [0.9148419 ],
#        [0.83675486],
#        [1.1579978 ],
#        [1.1908691 ],
#        [1.1810558 ],
#        [1.166542  ],
#        [1.1387249 ],
#        [1.0829201 ],
#        [1.0671344 ],
#        [0.99415886],
#        [0.9093577 ],
#        [1.0243336 ],
#        [1.1816293 ],
#        [1.2037688 ],
#        [1.1951427 ],
#        [1.1718998 ],
#        [1.1665047 ],
#        [0.6877966 ],
#        [1.1090319 ],
#        [1.0806305 ],
#        [1.15298   ],
#        [1.1738939 ],
#        [1.1496365 ],
#        [1.1180947 ],
#        [1.1277478 ],
#        [1.1338924 ],
#        [1.0631856 ],
#        [1.110459  ],
#        [1.159399  ],
#        [1.1520104 ],
#        [1.1256375 ],
#        [1.1462039 ],
#        [1.1562881 ],
#        [1.1306353 ],
#        [1.1471294 ],
#        [1.130486  ],
#        [1.1007519 ],
#        [1.0385027 ],
#        [1.1662327 ],
#        [1.1576526 ],
#        [1.0371746 ],
#        [1.1303275 ],
#        [0.97371864],
#        [1.0266182 ],
#        [1.1267688 ],
#        [1.112978  ],
#        [1.0900593 ],
#        [1.109368  ],
#        [1.0747302 ],
#        [0.93548465],
#        [1.0563812 ],
#        [1.0293319 ],
#        [1.0349276 ],
#        [1.1257348 ],
#        [1.153497  ],
#        [1.1004479 ],
#        [0.98364186],
#        [1.0635172 ],
#        [1.0338583 ],
#        [1.0055043 ],
#        [1.058824  ],
#        [1.0903301 ],
#        [1.1053106 ],
#        [1.0783813 ],
#        [0.99555844],
#        [1.0752617 ],
#        [0.9410093 ],
#        [0.86173564],
#        [1.0629048 ],
#        [1.1361115 ],
#        [1.1400872 ],
#        [1.0998061 ],
#        [1.0038813 ],
#        [0.887375  ],
#        [1.0344758 ],
#        [1.1104414 ],
#        [0.8618928 ],
#        [1.0669606 ],
#        [1.1492598 ],
#        [0.552539  ],
#        [1.0812706 ],
#        [0.9820769 ],
#        [0.7698095 ],
#        [1.0682471 ],
#        [0.84845465],
#        [1.1514709 ],
#        [1.0341825 ],
#        [1.0836376 ],
#        [0.65283424],
#        [0.93841064]], dtype=float32)

# %%
predicted_price = sc.inverse_transform(y_pred)

# %%
plt.plot(y_test, color = 'red', label = 'Actual Stock Price')
plt.plot(predicted_price, color = 'green', label = 'Predicted Stock Price')
plt.title('Google stock price prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
